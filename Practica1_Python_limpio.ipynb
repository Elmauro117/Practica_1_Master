# %% [markdown]
# ### Algoritmos:
#
# #### Merge, Bubble, Selection y Counting.

# %%
def Merge(sorted_left_array, sorted_right_array):
    
    # El nuevo array en donde vamos a appendear.
    arr_resultado = []
    
    # Itermaos los dos arrays 
    while len(sorted_left_array) > 0 and len(sorted_right_array) > 0:
        if sorted_left_array[0] > sorted_right_array[0]:
            arr_resultado.append(sorted_right_array[0])
            sorted_right_array.pop(0)
        else:
            arr_resultado.append(sorted_left_array[0])
            sorted_left_array.pop(0)
    
    while len(sorted_left_array) > 0:
        arr_resultado.append(sorted_left_array[0])
        sorted_left_array.pop(0)

    while len(sorted_right_array) > 0:
        arr_resultado.append(sorted_right_array[0])
        sorted_right_array.pop(0)
    
    return arr_resultado

def mergeSort(arr):
    #Primero miramos si se puede seguir dividiendo el problema
    if len(arr) == 1:
        return arr

    #Si todavia se puede dividir, se divide en dos
    middle = len(arr) // 2
    left_array = arr[:middle]
    right_array = arr[middle:]

    # Aplicas MergeSort recursivamente
    sorted_left_array = mergeSort(left_array)
    sorted_right_array = mergeSort(right_array)

    # Finalizamos aplicando la func MERGE a los dos array declarados arriba
    return Merge(sorted_left_array, sorted_right_array)

# %%
# Algoritmo Bubble Sort

def burble_sort(Lista):
    
    # Algoritmo
    swapped = False
    for i in range(len(Lista)-1):
        for j in range(0,len(Lista)-i-1):
            if Lista[j]> Lista[j+1]:
                swapped = True
                Lista[j],Lista[j+1]=Lista[j+1],Lista[j]
                      
        if not swapped:
            
            return 0
    return Lista

# %%
# Algoritmo Selection Sort
def selection_sort(Lista):
   
    # Algoritmo de ordenacion
    for i in range(len(Lista)-1):
        for j in range(i+1,len(Lista)):
            if Lista[i]>Lista[j]:
                Lista[i],Lista[j]=Lista[j],Lista[i]
                
    return Lista
                
                
# Algoritmo Counting Sort
def counting_sort(Lista):
          
    o = [0 for i in range(len(Lista))]   # tiene el tamaño del arreglo original  LISTA
    count = [0 for i in range(max(Lista)+1)] # arreglo con los numeros que llegan hasta el numero mas grande de la lista

    #contamos cuantas veces aparece cada elemento del arreglo
    for i in Lista:
        count[i] += 1
      

    #suma acumulativa, en el rango debe ir la cantidad de numeros q hay en el arreglo de la lista (hasta el num mas grand de la lista)
    for i in range(1,max(Lista)+1):
        count[i] += count[i-1]
       

    #ordenamos segun los indices
    for i in range(len(Lista)):
        o[count[Lista[i]]-1]=Lista[i]
        count[Lista[i]]-=1
    return o

# %% [markdown]
# ### Implementacion de los Algoritmos

# %%
from timeit import default_timer
import time
import numpy as np
import random

# %%
lista_tiempos_Mergesort = []
lista_tiempos_bubble_sort = []
lista_tiempos_selection_sort = []
lista_tiempos_counting_sort = []

# Aca metemos la cantidad de numeros q debe haber en cada array
n_listas = [100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000]

n= 1
        
for j in n_listas:
    

    lista_pre_tiempo_merge = []
    lista_pre_tiempo_bubble = []
    lista_pre_tiempo_selection = []
    lista_pre_tiempo_counting = []
    
    lista_tiempos_Mergesort.append(lista_pre_tiempo_merge)
    lista_tiempos_bubble_sort.append(lista_pre_tiempo_bubble)
    lista_tiempos_selection_sort.append(lista_pre_tiempo_selection)
    lista_tiempos_counting_sort.append(lista_pre_tiempo_counting)
    
    n= 1    
    while n < 6:
        
        randnums1= list(np.random.randint(1,50,j))
        randnums2= list(np.random.randint(1,50,j))
        randnums3= list(np.random.randint(1,50,j))
        randnums4= list(np.random.randint(1,50,j))

       # Mergesort
        #########################
        inicio_mergesort = default_timer()

        #print(randnums1)
        arr2 = mergeSort(randnums1)
        #print(arr2)
        
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
               

        fin_mergesort = default_timer()
        
        tiempos_merge = fin_mergesort-inicio_mergesort
        #########################
    # bubble_sort
        #########################
        inicio_bubble_sort = default_timer()

        #print(randnums2)
        arr2 = burble_sort(randnums2)
        #print(arr2)
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")

        fin_bubble_sort = default_timer()
        
        tiempos_bubble = fin_bubble_sort-inicio_bubble_sort
        #########################
        
        # # selection_sort
        #########################
        inicio_selection_sort = default_timer()

        #print(randnums3)
        arr2 = selection_sort(randnums3)
        #print(arr2)
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")

        fin_selection_sort = default_timer()
        
        tiempos_selection = fin_selection_sort-inicio_selection_sort
        #########################        
        
        # counting_sort
        #########################
        inicio_counting_sort = default_timer()

        #print(randnums4)
        arr2 = counting_sort(randnums4)
        #print(arr2)
        
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")

        fin_counting_sort = default_timer()
        
        tiempos_counting = fin_counting_sort-inicio_counting_sort
        #########################
        
        n+=1
               
        lista_pre_tiempo_merge.append(tiempos_merge)
        lista_pre_tiempo_bubble.append(tiempos_bubble)    
        lista_pre_tiempo_selection.append(tiempos_selection)    
        lista_pre_tiempo_counting.append(tiempos_counting)    

        print("tiempo de ejecicion del codigo es:")
        print(tiempos_merge, tiempos_bubble, tiempos_selection, tiempos_counting)
        print("*" * 100)
# Out:
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tiempo de ejecicion del codigo es:
# 0.0005093999789096415 0.0006935999845154583 0.00045470002805814147 6.629998097196221e-05
# ****************************************************************************************************
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# tiempo de ejecicion del codigo es:
# 0.0002918999525718391 0.0006282000103965402 0.00046010001096874475 5.069997860118747e-05
# ****************************************************************************************************
# ...

# %%
len(n_listas)
# Out:
# 15

# %%
#lista_tiempos_bubble_sort
lista_tiempos_Mergesort
#lista_tiempos_selection_sort
#lista_tiempos_counting_sort # las 5 runs que se hicieron en cada lista (tengo 3 listas)
# Out:
# [[0.0005093999789096415,
#   0.0002918999525718391,
#   0.0002589999930933118,
#   0.00025640003150328994,
#   0.00025720003759488463],
#  [0.003450999967753887,
#   0.0029122999985702336,
#   0.0028980999486520886,
#   0.0028824000037275255,
#   0.0029164000297896564],
#  [0.006358599988743663,
#   0.006368200003635138,
#   0.006408400018699467,
#   0.006386200024280697,
#   0.006330000003799796],
#  [0.010072799981571734,
#   0.010328800010029227,
#   0.01004980003926903,
#   0.01039199996739626,
#   0.011086300015449524],
#  [0.014735600037965924,
#   0.014072499994654208,
#   0.014630099991336465,
#   0.014063999988138676,
#   0.014908700017258525],
#  [0.019485299999359995,
#   0.019493800005875528,
#   0.01942530000815168,
#   0.018973800004459918,
#   0.019184799981303513],
#  [0.02389370003947988,
#   0.02320629998575896,
#   0.022978699998930097,
#   0.027944099972955883,
#   0.0233559999614954],
#  [0.028216500009875745,
#   0.029394199955277145,
#   0.028765800001565367,
# ...

# %% [markdown]
# ## Obtencion Promedios y Desvests

# %%
# Obtenemos el promedio y la desviacion estandar de los tiempos

lista_promedio_bubble = []
lista_promedio_Merge = []
lista_promedio_selection = []
lista_promedio_counting = []

lista_std_bubble = []
lista_std_Merge = []
lista_std_selection = []
lista_std_counting = []

# Promedio de cada tiempo de las 5 runs de cada Lista
# Desvest de cada tiempo de las 5 runs de cada Lista
for k in lista_tiempos_Mergesort:    
    promedio = np.average(k)
    lista_promedio_Merge.append(promedio) # Promedio de tiempo de las 5 runs de cada Lista
    
    st_dev = np.std(k)
    lista_std_Merge.append(st_dev) # Desvest de las 5 runs de cada Lista
    
for k in lista_tiempos_bubble_sort:    
    promedio = np.average(k)
    lista_promedio_bubble.append(promedio) # Promedio de tiempo de las 5 runs de cada Lista
    
    st_dev = np.std(k)
    lista_std_bubble.append(st_dev) # Desvest de las 5 runs de cada Lista
    
for k in lista_tiempos_selection_sort:    
    promedio = np.average(k)
    lista_promedio_selection.append(promedio) # Promedio de tiempo de las 5 runs de cada Lista
    
    st_dev = np.std(k)
    lista_std_selection.append(st_dev) # Desvest de las 5 runs de cada Lista
    
for k in lista_tiempos_counting_sort:    
    promedio = np.average(k)
    lista_promedio_counting.append(promedio) # Promedio de tiempo de las 5 runs de cada Lista
    
    st_dev = np.std(k)
    lista_std_counting.append(st_dev) # Desvest de las 5 runs de cada Lista

# %%
print(lista_promedio_Merge,
      lista_promedio_bubble, 
      lista_promedio_selection,
      lista_promedio_counting)
# Out:
# [0.0003147799987345934, 0.0030120399896986783, 0.0063702800078317525, 0.010385940002743154, 0.01448218000587076, 0.019312599999830128, 0.024275759991724044, 0.028834239998832344, 0.033690440002828836, 0.03997215999988839, 0.04488445998867974, 0.1066795399878174, 0.18940909998491406, 0.3031990199931897, 0.42263701998163017] [0.0006370199960656464, 0.07142907999223098, 0.3127250600024126, 0.7253236399963499, 1.3223082999931648, 2.1059670800110326, 3.0186925200046972, 4.077137100009713, 5.357379860000219, 6.744879640021827, 8.067697459994815, 31.980132480023894, 71.92262963999528, 132.01200366000413, 208.47591371998425] [0.00044958001235499977, 0.03741121998755261, 0.1483673599897884, 0.34612812000559645, 0.6156592199928127, 0.962505979987327, 1.37671616000589, 1.86980884000659, 2.4560267599881627, 3.088124600017909, 3.729589080007281, 14.6120754799922, 32.80317598000401, 60.218272679985965, 96.17473060000921] [5.315999733284116e-05, 0.00038534000050276517, 0.0007883800193667412, 0.0012
# ...

# %%
lista_promedio_Merge
# Out:
# [0.0003147799987345934,
#  0.0030120399896986783,
#  0.0063702800078317525,
#  0.010385940002743154,
#  0.01448218000587076,
#  0.019312599999830128,
#  0.024275759991724044,
#  0.028834239998832344,
#  0.033690440002828836,
#  0.03997215999988839,
#  0.04488445998867974,
#  0.1066795399878174,
#  0.18940909998491406,
#  0.3031990199931897,
#  0.42263701998163017]

# %%
print(lista_std_Merge,
      lista_std_bubble, 
      lista_std_selection,
      lista_std_counting)
# Out:
# [9.821966679221197e-05, 0.0002198043625646362, 2.6343159037821746e-05, 0.0003754604099610594, 0.00034949494809004245, 0.00020321333888423997, 0.0018587498953589472, 0.00039473047498404313, 0.001163755326171139, 0.0009291622266294388, 0.0022815345628858343, 0.0004781897517998251, 0.0014773438731349863, 0.007222073362595057, 0.00676275680852857] [2.851331777688214e-05, 0.0007983946724742264, 0.006302156267447216, 0.019412543369391057, 0.023652951867434237, 0.02258938214699329, 0.03726302337675564, 0.034634876133015094, 0.04946659822371679, 0.029849216535200482, 0.1509700895381789, 0.46228638810688016, 0.5086225849932893, 2.6882644931180595, 5.280520887686879] [6.634279252311396e-06, 0.0005025193307244256, 0.0011010808945119623, 0.008123186694241722, 0.012518994445490492, 0.009747522529692723, 0.023284976193267706, 0.013211964807431299, 0.027596905248346914, 0.00870545488637983, 0.057510490941335105, 0.1486330327487267, 0.16506801240979807, 1.697486129827512, 3.2343108208668916] [6.5950
# ...
